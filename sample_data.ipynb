# %%
import pandas as pd

sample_date = pd.Timestamp(1989,6,1)
df = pd.read_pickle('./data/input/Tiananmen_sentences.pkl')
sample_df = df[df['date']==pd.Timestamp(1989,6,1)]

sample_df[['id','date','sentence']]
# Out:
#           id       date                                           sentence
# 135   433415 1989-06-01                                       神圣的天安门广场不容亵渎
# 139   433421 1989-06-01                            《北京日报》发表一位外地大学生离京时的反思文章
# 140   433421 1989-06-01                                       天安门广场啊，我为你哭泣
# 141   433428 1989-06-01                                        就限制外国记者采访一事
# 142   433428 1989-06-01                                        北京市府发言人发表谈话
# 143   433437 1989-06-01                                       首都四十家企业负责人要求
# 144   433437 1989-06-01                                      取缔盗用工人名义的非法组织
# 1623  433415 1989-06-01                                晨，天安门广场突然冒出一个什么女神像。
# 1624  433415 1989-06-01                       这是公然违反法律规定、违背民意、亵渎人民神圣情感的行为。
# 1625  433415 1989-06-01                                      首都人民对此表示强烈不满。
# 1626  433415 1989-06-01                            天安门广场是我国各族人民向往、景仰的神圣地方。
# ...

# %%
sample_result = pd.read_excel('./results/data/with text/predict_df_HK2019.xlsx')
sample_result[['id','date','sentence','predict']]
# Out:
#                 id       date  \
# 5      20190615078 2019-06-15
# 6      20190615079 2019-06-15
# 7      20190616042 2019-06-16
# 8      20190616044 2019-06-16
# 9      20190616046 2019-06-16
# 10     20190616047 2019-06-16
# 11     20190616048 2019-06-16
# 12    201906160411 2019-06-16
# 18     20190630042 2019-06-30
# 19     20190630042 2019-06-30
# 21     20190701065 2019-07-01
# 23     20190703015 2019-07-03
# 24     20190703045 2019-07-03
# 25     20190703046 2019-07-03
# 26     20190703047 2019-07-03
# 27     20190703048 2019-07-03
# 28     20190703049 2019-07-03
# 29    201907030410 2019-07-03
# 30    201907030411 2019-07-03
# 33     20190705047 2019-07-05
# 34     20190705048 2019-07-05
# 52     20190721013 2019-07-21
# 53     20190721013 2019-07-21
# 54     20190721042 2019-07-21
# 57     20190722014 2019-07-22
# 58     20190722047 2019-07-22
# 59     20190722049 2019-07-22
# 60    201907220410 2019-07-22
# 65     20190724044 2019-07-24
# 66     20190724045 2019-07-24
# ...
